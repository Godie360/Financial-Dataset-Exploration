# %% [markdown]
# ## <center> Exploratory Data Anaysis on how  Sales and Profit  varry with countries or market segment </center>

# %% [markdown]
# ### Problem Statement
# Trade participants often conduct trade without knowledge on a wider scope markert but rather focus on competition between themselves in a microlevel.
#
# Normally traders compete with in a limited market and hence focus on how the their fellow traders conduct bussiness. Small scale traders focus on competition between them selves meaning exploring markets that may be limited to their locality
#
# The objective of analysis of this data set is to come up with a model that will provide a bloder scope of analysis on sales and profit generated by bussiness offering the same product over a wider range and come with general solutions that can be applied by participants or facilitators to improve the bussines

# %% [markdown]
# ## HYPOTHESIS
#
# The following are the possible factors blind the scope of analysis.
#
#    * All products results to the same sales accumulation and result to same profits.
#
#    * Cost of production is the same or of minimum variation among participants.
#
#    * Our location is the best in sells performance and profit among others
#
#    * Sales for our products best corresponds to the profit generated.
#
#    * Product sales is fairly distributed through out the course of the year
#
#    * All participants have equal share of the market

# %%
# Importint the necessary librabries that will be used for analyzing data 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading financial data for analysis
path = "Financials.csv"
financial_data = pd.read_csv(path)

# %% [markdown]
# # CLEANING DATA

# %%
# Checking fo possibe null values
financial_data.isnull().sum()
# Out:
# Segment                  0
# Country                  0
#  Product                 0
#  Discount Band           0
#  Units Sold              0
#  Manufacturing Price     0
#  Sale Price              0
#  Gross Sales             0
# Discounts                0
# Sales                    0
#  COGS                    0
#  Profit                  0
# Date                     0
# Month Number             0
#  Month Name              0
# Year                     0
# dtype: int64

# %%
# Checking for number of rows and columns respectively
financial_data.shape
# Out:
# (700, 16)

# %%
#checking for metadata details
financial_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                700 non-null    object
#  1   Country                700 non-null    object
#  2    Product               700 non-null    object
#  3    Discount Band         700 non-null    object
#  4    Units Sold            700 non-null    object
#  5    Manufacturing Price   700 non-null    object
#  6    Sale Price            700 non-null    object
#  7    Gross Sales           700 non-null    object
#  8   Discounts              700 non-null    object
#  9   Sales                  700 non-null    object
#  10   COGS                  700 non-null    object
#  11   Profit                700 non-null    object
#  12  Date                   700 non-null    object
#  13  Month Number           700 non-null    int64
#  14   Month Name            700 non-null    object
#  15  Year                   700 non-null    int64
# dtypes: int64(2), object(14)
# memory usage: 87.6+ KB

# %%
# Overview of sample data 
financial_data.head(10)
# Out:
#             Segment  Country     Product   Discount Band   Units Sold   \
# 0        Government   Canada   Carretera            None    $1,618.50
# 1        Government  Germany   Carretera            None    $1,321.00
# 2         Midmarket   France   Carretera            None    $2,178.00
# 3         Midmarket  Germany   Carretera            None      $888.00
# 4         Midmarket   Mexico   Carretera            None    $2,470.00
# 5        Government  Germany   Carretera            None    $1,513.00
# 6         Midmarket  Germany     Montana            None      $921.00
# 7  Channel Partners   Canada     Montana            None    $2,518.00
# 8        Government   France     Montana            None    $1,899.00
# 9  Channel Partners  Germany     Montana            None    $1,545.00
#
#    Manufacturing Price   Sale Price     Gross Sales  Discounts   \
# 0                $3.00       $20.00      $32,370.00       $-
# 1                $3.00       $20.00      $26,420.00       $-
# 2                $3.00       $15.00      $32,670.00       $-
# 3                $3.00       $15.00      $13,320.00       $-
# 4                $3.00       $15.00      $37,050.00       $-
# 5                $3.00      $350.00    $5,29,550.00       $-
# 6                $5.00       $15.00      $13,815.00       $-
# 7                $5.00       $12.00      $30,216.00       $-
# 8                $5.00       $20.00      $37,980.00       $-
# 9                $5.00       $12.00      $18,540.00       $-
#
#            Sales            COGS          Profit         Date  Month Number  \
# 0     $32,370.00      $16,185.00      $16,185.00   01/01/2014             1
# 1     $26,420.00      $13,210.00      $13,210.00   01/01/2014             1
# 2     $32,670.00      $21,780.00      $10,890.00   01/06/2014             6
# 3     $13,320.00       $8,880.00       $4,440.00   01/06/2014             6
# 4     $37,050.00      $24,700.00      $12,350.00   01/06/2014             6
# 5   $5,29,550.00    $3,93,380.00    $1,36,170.00   01/12/2014            12
# 6     $13,815.00       $9,210.00       $4,605.00   01/03/2014             3
# 7     $30,216.00       $7,554.00      $22,662.00   01/06/2014             6
# 8     $37,980.00      $18,990.00      $18,990.00   01/06/2014             6
# 9     $18,540.00       $4,635.00      $13,905.00   01/06/2014             6
#
#    Month Name   Year
# 0     January   2014
# 1     January   2014
# 2        June   2014
# 3        June   2014
# 4        June   2014
# 5    December   2014
# 6       March   2014
# 7        June   2014
# 8        June   2014
# 9        June   2014

# %%
# The code removes space between names of the column
financial_data.columns = financial_data.columns.str.replace(' ', '')

# %%
# #=reviewing data
financial_data.head(10)
# Out:
#             Segment  Country      Product DiscountBand    UnitsSold  \
# 0        Government   Canada   Carretera         None    $1,618.50
# 1        Government  Germany   Carretera         None    $1,321.00
# 2         Midmarket   France   Carretera         None    $2,178.00
# 3         Midmarket  Germany   Carretera         None      $888.00
# 4         Midmarket   Mexico   Carretera         None    $2,470.00
# 5        Government  Germany   Carretera         None    $1,513.00
# 6         Midmarket  Germany     Montana         None      $921.00
# 7  Channel Partners   Canada     Montana         None    $2,518.00
# 8        Government   France     Montana         None    $1,899.00
# 9  Channel Partners  Germany     Montana         None    $1,545.00
#
#   ManufacturingPrice  SalePrice      GrossSales Discounts           Sales  \
# 0             $3.00     $20.00      $32,370.00      $-        $32,370.00
# 1             $3.00     $20.00      $26,420.00      $-        $26,420.00
# 2             $3.00     $15.00      $32,670.00      $-        $32,670.00
# 3             $3.00     $15.00      $13,320.00      $-        $13,320.00
# 4             $3.00     $15.00      $37,050.00      $-        $37,050.00
# 5             $3.00    $350.00    $5,29,550.00      $-      $5,29,550.00
# 6             $5.00     $15.00      $13,815.00      $-        $13,815.00
# 7             $5.00     $12.00      $30,216.00      $-        $30,216.00
# 8             $5.00     $20.00      $37,980.00      $-        $37,980.00
# 9             $5.00     $12.00      $18,540.00      $-        $18,540.00
#
#              COGS          Profit        Date  MonthNumber   MonthName  Year
# 0     $16,185.00      $16,185.00   01/01/2014            1    January   2014
# 1     $13,210.00      $13,210.00   01/01/2014            1    January   2014
# 2     $21,780.00      $10,890.00   01/06/2014            6       June   2014
# 3      $8,880.00       $4,440.00   01/06/2014            6       June   2014
# 4     $24,700.00      $12,350.00   01/06/2014            6       June   2014
# 5   $3,93,380.00    $1,36,170.00   01/12/2014           12   December   2014
# 6      $9,210.00       $4,605.00   01/03/2014            3      March   2014
# 7      $7,554.00      $22,662.00   01/06/2014            6       June   2014
# 8     $18,990.00      $18,990.00   01/06/2014            6       June   2014
# 9      $4,635.00      $13,905.00   01/06/2014            6       June   2014

# %%
# function to remove dollar Sign 
financial_data['UnitsSold'] = financial_data['UnitsSold'].str.replace('$', '')
financial_data['ManufacturingPrice'] = financial_data['ManufacturingPrice'].str.replace('$', '')
financial_data['SalePrice'] = financial_data['SalePrice'].str.replace('$', '')
financial_data['Sales'] = financial_data['Sales'].str.replace('$', '')
financial_data['COGS'] = financial_data['COGS'].str.replace('$', '')
financial_data['Profit'] = financial_data['Profit'].str.replace('$', '')
financial_data['Sales'] = financial_data['Sales'].str.replace('$', '')
financial_data['GrossSales'] = financial_data['GrossSales'].str.replace('$', '')



# function to remove comma Sign and convert data to numerical(float)
financial_data['UnitsSold'] = financial_data['UnitsSold'].str.replace(',', '')
financial_data['ManufacturingPrice'] = financial_data['ManufacturingPrice'].str.replace('$', '')
financial_data['SalePrice'] = financial_data['SalePrice'].str.replace(',', '')
financial_data['Sales'] = financial_data['Sales'].str.replace(',', '')
financial_data['COGS'] = financial_data['COGS'].str.replace(',', '')
financial_data['Profit'] = financial_data['Profit'].str.replace(',', '')
financial_data['Sales'] = financial_data['Sales'].str.replace(',', '')
financial_data['GrossSales'] = financial_data['GrossSales'].str.replace(',', '')




# Stripping the spaces 
financial_data['UnitsSold'] = financial_data['UnitsSold'].str.strip()
financial_data['ManufacturingPrice'] = financial_data['ManufacturingPrice'].str.strip()
financial_data['SalePrice'] = financial_data['SalePrice'].str.strip()
financial_data['Sales'] = financial_data['Sales'].str.strip()
financial_data['COGS'] = financial_data['COGS'].str.strip()
financial_data['Profit'] = financial_data['Profit'].str.strip()
financial_data['Sales'] = financial_data['Sales'].str.strip()
financial_data['GrossSales'] = financial_data['GrossSales'].str.strip()
# Out:
# C:\Users\Black Alpha\AppData\Local\Temp\ipykernel_17056\3111435376.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   financial_data['UnitsSold'] = financial_data['UnitsSold'].str.replace('$', '')
# C:\Users\Black Alpha\AppData\Local\Temp\ipykernel_17056\3111435376.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   financial_data['ManufacturingPrice'] = financial_data['ManufacturingPrice'].str.replace('$', '')
# C:\Users\Black Alpha\AppData\Local\Temp\ipykernel_17056\3111435376.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   financial_data['SalePrice'] = financial_data['SalePrice'].str.replace('$', '')
# C:\Users\Black Alpha\AppData\Local\Temp\ipykernel_17056\3111435376.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   financial_data['Sales'] = financial_data['Sales'].str.replace('$', '')
# C:\Users\Black Alpha\AppData\Local\Temp\ipykernel_17056\3111435376.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   financial_data['COGS'] = financial_data['COGS'].str.replace('$', '')
# C:\Users\Black Alpha\AppData\Local\Temp\ipykernel_17056\3111435376.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   financial_data['Profit'] = financial_data['Profit'].str.replace('$', '')
# C:\Users\Black Alpha\AppData\Local\Temp\ipykernel_17056\3111435376.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   financial_data['Sales'] = financial_data['Sales'].str.replace('$', '')
# C:\Users\Black Alpha\AppData\Local\Temp\ipykernel_17056\3111435376.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   financial_data['GrossSales'] = financial_data['GrossSales'].str.replace('$', '')
# C:\Users\Black Alpha\AppData\Local\Temp\ipykernel_17056\3111435376.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   financial_data['ManufacturingPrice'] = financial_data['ManufacturingPrice'].str.replace('$', '')

# %%
# Proof checking Top data
financial_data.head(10)
# Out:
#             Segment  Country      Product DiscountBand UnitsSold  \
# 0        Government   Canada   Carretera         None    1618.50
# 1        Government  Germany   Carretera         None    1321.00
# 2         Midmarket   France   Carretera         None    2178.00
# 3         Midmarket  Germany   Carretera         None     888.00
# 4         Midmarket   Mexico   Carretera         None    2470.00
# 5        Government  Germany   Carretera         None    1513.00
# 6         Midmarket  Germany     Montana         None     921.00
# 7  Channel Partners   Canada     Montana         None    2518.00
# 8        Government   France     Montana         None    1899.00
# 9  Channel Partners  Germany     Montana         None    1545.00
#
#   ManufacturingPrice SalePrice GrossSales Discounts      Sales       COGS  \
# 0               3.00     20.00   32370.00     $-      32370.00   16185.00
# 1               3.00     20.00   26420.00     $-      26420.00   13210.00
# 2               3.00     15.00   32670.00     $-      32670.00   21780.00
# 3               3.00     15.00   13320.00     $-      13320.00    8880.00
# 4               3.00     15.00   37050.00     $-      37050.00   24700.00
# 5               3.00    350.00  529550.00     $-     529550.00  393380.00
# 6               5.00     15.00   13815.00     $-      13815.00    9210.00
# 7               5.00     12.00   30216.00     $-      30216.00    7554.00
# 8               5.00     20.00   37980.00     $-      37980.00   18990.00
# 9               5.00     12.00   18540.00     $-      18540.00    4635.00
#
#       Profit        Date  MonthNumber   MonthName  Year
# 0   16185.00  01/01/2014            1    January   2014
# 1   13210.00  01/01/2014            1    January   2014
# 2   10890.00  01/06/2014            6       June   2014
# 3    4440.00  01/06/2014            6       June   2014
# 4   12350.00  01/06/2014            6       June   2014
# 5  136170.00  01/12/2014           12   December   2014
# 6    4605.00  01/03/2014            3      March   2014
# 7   22662.00  01/06/2014            6       June   2014
# 8   18990.00  01/06/2014            6       June   2014
# 9   13905.00  01/06/2014            6       June   2014

# %%
# Conevrting columns types to numerical (float) data type

financial_data['UnitsSold'] = pd.to_numeric(financial_data['UnitsSold'])
financial_data['ManufacturingPrice'] = pd.to_numeric(financial_data['ManufacturingPrice'])
financial_data['SalePrice'] = pd.to_numeric(financial_data['SalePrice'])
financial_data['Sales'] = pd.to_numeric(financial_data['Sales'])
financial_data['COGS'] = pd.to_numeric(financial_data['COGS'])
financial_data['Profit'] = pd.to_numeric(financial_data['Profit'], errors='coerce')
financial_data['Sales'] = pd.to_numeric(financial_data['Sales'])
financial_data['GrossSales'] = pd.to_numeric(financial_data['GrossSales'])

# %%
# Relacing the null values with zero
financial_data['Profit'].fillna(0, inplace=True)

# %%
# proof checking the meta data 
financial_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Segment             700 non-null    object
#  1   Country             700 non-null    object
#  2   Product             700 non-null    object
#  3   DiscountBand        700 non-null    object
#  4   UnitsSold           700 non-null    float64
#  5   ManufacturingPrice  700 non-null    float64
#  6   SalePrice           700 non-null    float64
#  7   GrossSales          700 non-null    float64
#  8   Discounts           700 non-null    object
#  9   Sales               700 non-null    float64
#  10  COGS                700 non-null    float64
#  11  Profit              700 non-null    float64
#  12  Date                700 non-null    object
#  13  MonthNumber         700 non-null    int64
#  14  MonthName           700 non-null    object
#  15  Year                700 non-null    int64
# dtypes: float64(7), int64(2), object(7)
# memory usage: 87.6+ KB

# %% [markdown]
# <!-- # DATA PLOTS -->

# %% [markdown]
# ## A.Univariate Analysis

# %% [markdown]
# <!-- # Histogram -->

# %% [markdown]
# <!-- #  Creating a figure with two subplots in a single row
# fig, axs = plt.subplots(1, 2, figsize=(20, 8))
#
#
#
# # Histogram code
# sns.histplot(data=financial_data, x="Sales", ax=axs[0])
# #Title
# axs[0].set_title("Sales Distribution among Salers")
#
#
# # Histogram code
# sns.histplot(data=financial_data, x="Profit", ax=axs[1])
# #Title
# axs[1].set_title("Profit Distribution among Salers")
#
# # Fitting the graph properly
# plt.tight_layout()
#
# # Displaying the visualization
# plt.show() -->

# %% [markdown]
# <!-- ### Purpose
# * To visualize the distribution of sales amount made among firms and the number of corresponding firms.
#
# ### Use
# * In tax assesment to ensure sustainable bussiness activities and significant government revenue
#
# ### Insight
# * Majority of the sales fell bellow 400000 dollars and profits fell bellow 50000 dollars
#
#  -->

# %%
# Set the figure size
plt.figure(figsize=(6, 6))  

# E# Pie Chartxtracting data to be used for the pie chart from the data frame
x = financial_data['Segment'].value_counts()

# Seleting a set of bright colors to be used 
palette_color = sns.color_palette('bright')

# Pie chart code
plt.pie(x.values, labels=x.index, autopct='%1.1f%%',colors=palette_color, startangle=140)

# Plot Title
plt.title("Participants in Trading Activities")

# Fitting the graph properly
plt.tight_layout()

# Displaying the visualization
plt.show()

# %% [markdown]
# ### All participants have equal share of the market

# %% [markdown]
# #### Government segment dominate the market hence have an edge

# %% [markdown]
# <!-- # Bar Plots -->

# %% [markdown]
# <!-- ## Vertical -->

# %% [markdown]
# ## B. Bivariate Analysis

# %%
#  Creating a figure with two subplots in a single row
fig, axs = plt.subplots(1, 2, figsize=(15, 6))

# Vertical Barplot code
sns.barplot(x="Country", y="Sales", data=financial_data , ax=axs[0])

# Plot Title
axs[0].set_title("Mean Sales among Countries")



# Vertical Barplot code
sns.barplot(x="Country", y="Profit", data=financial_data , ax=axs[1])

# Plot Title
axs[1].set_title("Mean Profit among Countries")



# Fitting the graph properly
plt.tight_layout()

# Displaying the visualization
plt.show()

# %% [markdown]
# ### Our location is the best in sells performance and profit among others

# %% [markdown]
# #### Location sales and profits vary.

# %% [markdown]
# <!-- ### Purpose
# * Visualizes the mean amount made in sales and profit among countries.
#
# ### Use
# * It helpful in accessing average incomes generated by governments hence foundation for bussiness strategy planning
#
# ### Insight
# * All countries had a fair share of sales except mexico. France had the major share of profits while mexico had least. However the cost of goods is high for USA compared to other countries due to high sales and inrelative profit
#
#  -->

# %% [markdown]
# <!-- ## Horizontal -->

# %%
#  Creating a figure with two subplots in a single row
fig, axs = plt.subplots(1, 2, figsize=(10, 4))

# Horizontal Barplot code
sns.barplot(y="Product", x="Profit", data=financial_data, orient="h", ax=axs[0])
# Plot Title
axs[0].set_title("Mean Profit for products")



# Horizontal Barplot code
sns.barplot(y="Product", x="Sales", data=financial_data, orient="h", ax=axs[1])
# Plot Title
axs[1].set_title("Mean Sales for products")


# Fitting the graph properly
plt.tight_layout()

# Displaying the visualization
plt.show()

# %% [markdown]
# <!-- ### Purpose
# * Visualizes the mean amount made in sales and profit among sold products.
#
# ### Use
# * It helpful in accessing average incomes generated from produccts hence finding stratergies to improve product incomes as well as product selcetion for saling.
#
# ### Insight
# * Sales of products corresponded to profit attained. Except for vello which may indicate higher cost of goods for the product.
#  -->

# %% [markdown]
# ### Sales for our products best corresponds to the profit generated.

# %% [markdown]
# #### Products vary in sales and higher sells mostly correspond to high profits

# %% [markdown]
# <!-- # Pie Chart -->

# %% [markdown]
# <!-- # Set the figure size
# plt.figure(figsize=(6, 6))
#
# # E# Pie Chartxtracting data to be used for the pie chart from the data frame
# x = financial_data['Segment'].value_counts()
#
# # Seleting a set of bright colors to be used
# palette_color = sns.color_palette('bright')
#
# # Pie chart code
# plt.pie(x.values, labels=x.index, autopct='%1.1f%%',colors=palette_color, startangle=140)
#
# # Plot Title
# plt.title("Participants in Trading Activities")
#
# # Fitting the graph properly
# plt.tight_layout()
#
# # Displaying the visualization
# plt.show() -->

# %% [markdown]
# <!-- ### Purpose
# * Visualizes market sharing among types of participants
#
# ### Use
# * Foundation for balancing policies for participants in the market and access any limitations
#
# ### Insight
# * Government bonded participants dominated the market while others had an equal share of the market.
#  -->

# %% [markdown]
# <!-- # Box Plot -->

# %%
# Setting the figure size
plt.figure(figsize=(8, 6))

# Creating a box plot
sns.boxplot(x="Segment", y="COGS", data=financial_data)


# Plot Title
plt.title("Participants cost of goods Sold")

# Fitting the graph properly
plt.tight_layout()

# Displaying the visualization
plt.show()

# %% [markdown]
# ### Cost of production is the same or of minimum variation among participants.

# %% [markdown]
# #### Cost of production is lower for government sectors, mid for enterprises and high for small bussiness. Least for channels partners as the do not product goods

# %% [markdown]
# <!-- ### Purpose
# * Visualizes the cost of goods experienced between market segments (participants).
#
# ### Use
# * Bases for balancing expenses experienced by firms especially on the build up to create and market products.
#
# ### Insight
# * Small Bussiness had highest expenses, with enterprises having slightly less where by government segment had among the fair cost of goods
#  -->

# %% [markdown]
# <!-- # Joint Plot -->

# %%
plt.figure(figsize=(6, 1))
sns.jointplot(x="MonthNumber", y="Sales", data=financial_data, kind="kde")

# Fitting the graph properly
plt.tight_layout()

# Add title 
plt.title("Sales distribution throughout months of the year")
plt.show()

# %% [markdown]
# ### Product sales is fairly distributed through out the course of the year

# %% [markdown]
# #### Product sales are fair during the early months, low in the mid of the year   while high during the end of the year

# %% [markdown]
# <!-- ### Purpose
# * Visualizes the relationship between sales and months
#
# ### Use
# * For determining which months are best to conduct bussiness and what prices are best for products as per sales achieved
#
# ### Insight
# * End months had good sales performance and the most accumulation of sales where below 400000 dollars
#  -->

# %% [markdown]
# ## C. Multivariate Analysis

# %%
# Setting the figure size
plt.figure(figsize=(8, 6))  

correlation_matrix = financial_data.corr()

# Creating a heat map
sns.heatmap(data=correlation_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1)

# Plot Title
plt.title("Heat map showing distribution of various parameters")

# Fitting the graph properly
plt.tight_layout()

# Displaying the visualization
plt.show()
# Out:
# C:\Users\Black Alpha\AppData\Local\Temp\ipykernel_17056\3178761195.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = financial_data.corr()

# %% [markdown]
# <!-- ### Purpose
# * Visualizes dependency between various aspects in the sales.
#
# ### Use
# * Foundation for understanding on which aspect are to be considered most for trading purposes.
#
# ### Insight
# * Months any year had minimum to no impact in trading while the financial terms such has profit, sales, cost of goods, sale price and gross sales largely affect each other and trading in general
#  -->

# %% [markdown]
# #### Overall variations for products and other factors
